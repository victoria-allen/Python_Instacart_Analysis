# %% [markdown]
# ## 00. Import Libraries

# %%
# import libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 01. Import Data

# %%
# Create folderpath

path = r'C:\Users\Victoria\Desktop\Data Analytics Career Foundry\4.0 Python Fundamentals for Data Analysts\Instacart Basket Analysis'

# %%
# Import orders_products_merged from exercise 4.7

ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merged_nv.pkl'))

# %%
# Create a subset of the first million entries

df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 18)

# %%
df.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_the_week  order_hour_of_day  \
# 0   2539329        1             1                       2                  8
# 1   2398795        1             2                       3                  7
# 2    473747        1             3                       3                 12
# 3   2254736        1             4                       4                  7
# 4    431534        1             5                       4                 15
# 5   3367565        1             6                       2                  7
# 6    550135        1             7                       1                  9
# 7   3108588        1             8                       1                 14
# 8   2295261        1             9                       1                 16
# 9   2550362        1            10                       4                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# ...

# %%
# Try the groupby() function

df.groupby('product_name')

# %%
# Use the first two steps, grouping the data, and applying an agg() function

df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %% [markdown]
# Here, the groupby() function is being assigned to the df dataframe. This creates the pandas object for “department_id.” Onto this resulting object, the agg() function is applied. The agg() function will return the mean of the given column, in this case, “order_number.”

# %%
# Perform aggregation without using agg() function
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %%
# Perform mutiple aggregations

df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %%
# locate these loyalty customers

ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_the_week  \
# 0    2539329        1             1                       2
# 1    2398795        1             2                       3
# 2     473747        1             3                       3
# 3    2254736        1             4                       4
# 4     431534        1             5                       4
# 5    3367565        1             6                       2
# 6     550135        1             7                       1
# 7    3108588        1             8                       1
# 8    2295261        1             9                       1
# 9    2550362        1            10                       4
# 10   2968173       15            15                       1
# 11   1870022       15            17                       2
# 12   1911383       15            18                       2
# 13   2715276       15            21                       1
# 14    487368       15            22                       1
#
# ...

# %%
ords_prods_merge.head(100)
# Out:
#     order_id  user_id  order_number  orders_day_of_the_week  \
# 0    2539329        1             1                       2
# 1    2398795        1             2                       3
# 2     473747        1             3                       3
# 3    2254736        1             4                       4
# 4     431534        1             5                       4
# ..       ...      ...           ...                     ...
# 95   3226575      360             1                       5
# 96   1469869      377             3                       5
# 97   1927023      387             2                       4
# 98    858092      420             4                       1
# 99    119314      420             5                       3
#
#     order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                   8                     NaN         196                  1
# 1                   7                    15.0         196                  1
# ...

# %%
pd.options.display.max_rows = None

# %%
# ords_prods_merge.head(100)

# %%
# deriving columns with the loc()
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             2
# 2         1      New customer             3
# 3         1      New customer             4
# 4         1      New customer             5
# 5         1      New customer             6
# 6         1      New customer             7
# 7         1      New customer             8
# 8         1      New customer             9
# 9         1      New customer            10
# 10       15  Regular customer            15
# 11       15  Regular customer            17
# 12       15  Regular customer            18
# 13       15  Regular customer            21
# 14       15  Regular customer            22
# 15       19      New customer             2
# 16       19      New customer             5
# 17       19      New customer             7
# 18       21  Regular customer            10
# 19       31  Regular customer            10
# ...

# %% [markdown]
# As always, after executing your code, you should check that everything was interpreted correctly and that the right flags were assigned. To do this without looking at the entire dataframe and constantly having to scroll left and right, which is both tedious and prone to error, you can try this method, which will limit the output of your head() function to just those columns you want to check. You learned already that to access a single column in a dataframe, you can index it like so:
#
# df['column']
# Well, a similar syntax can be used to access multiple columns at the same time. For instance, if you wanted to write a head() function that returned the first 60 rows of only the “user_id,” “loyalty_flag,” and “order_number” columns, you could format it as follows:
#
# ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# While this may seem somewhat complicated, if you look more closely, you’ll see that it’s all things you’ve dealt with before—just all at the same time. The first set of brackets is the same as the brackets used in df['column'] above, while the second set of brackets is indicating that what you’re indexing is a list of multiple columns (and lists are always included within brackets). This is why there are two sets of brackets.
#
# The code itself will display the first 60 rows of just the “user_id,” “loyalty_flag,” and “order_number” columns, which will make it much easier for you to quickly confirm the numbers and ensure accuracy of the flag labels.
#
# And that brings you to the end of the three-step process! You started by grouping your data, followed up by applying an aggregation function, and finished everything off by using the resulting aggregation to create a flag column. This will be a process you’ll become quite familiar with the more you work with dataframes in Python, and though it may divert slightly depending on what you’re trying to do and the data you’re working with, the basic workflow will stay the same.
